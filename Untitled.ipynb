# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Buyer\Perovskite-sq-audit1

# %%
Eg_eV = 1.34                      # bandgap in electron-volts

q = 1.602e-19                     # charge of one electron, in Coulombs
Eg_J = Eg_eV * q                  # convert eV -> Joules

cutoff_wavelength_m = h * c / Eg_J        # E = hc/λ  ->  λ = hc/E
cutoff_wavelength_nm = cutoff_wavelength_m * 1e9   # meters -> nm

print(cutoff_wavelength_nm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       2
#       3 q = 1.602e-19                     # charge of one electron, in Coulombs
#       4 Eg_J = Eg_eV * q                  # convert eV -> Joules
#       5
# ----> 6 cutoff_wavelength_m = h * c / Eg_J        # E = hc/λ  ->  λ = hc/E
#       7 cutoff_wavelength_nm = cutoff_wavelength_m * 1e9   # meters -> nm
#       8
#       9 print(cutoff_wavelength_nm)
#
# NameError: name 'h' is not defined

# %%
h = 6.626e-34
c = 3.0e8

# %%
h = 6.626e-34                     # Planck's constant, J·s
c = 3.0e8                         # speed of light, m/s

Eg_eV = 1.34                      # bandgap in electron-volts
q = 1.602e-19                     # charge of one electron, in Coulombs
Eg_J = Eg_eV * q                  # convert eV -> Joules

cutoff_wavelength_m = h * c / Eg_J        # E = hc/λ  ->  λ = hc/E
cutoff_wavelength_nm = cutoff_wavelength_m * 1e9   # meters -> nm

print(cutoff_wavelength_nm)
# Out:
# 925.988037341383

# %%
D
