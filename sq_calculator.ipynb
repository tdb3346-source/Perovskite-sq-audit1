# %%
import numpy as np
print(np.__version__)
# Out:
# 2.4.6

# %%
import pvlib
import numpy as np
import matplotlib.pyplot as plt

spectra = pvlib.spectrum.get_reference_spectra()
spectra.head()
# Out:
#             extraterrestrial        global        direct
# wavelength
# 280.0                  0.082  4.730900e-23  2.536100e-26
# 280.5                  0.099  1.230700e-21  1.091700e-24
# 281.0                  0.150  5.689500e-21  6.125300e-24
# 281.5                  0.212  1.566200e-19  2.747900e-22
# 282.0                  0.267  1.194600e-18  2.834600e-21

# %%
plt.figure(figsize=(10, 5))
plt.plot(spectra.index, spectra['global'])
plt.xlabel('Wavelength (nm)')
plt.ylabel('Spectral irradiance (W/m²/nm)')
plt.title('AM1.5G Solar Spectrum')
plt.show()

# %%
total_power = np.trapz(spectra['global'], spectra.index)
print(total_power)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 total_power = np.trapz(spectra['global'], spectra.index)
#       2 print(total_power)
#
# File ~\miniconda3\envs\psc\Lib\site-packages\numpy\__init__.py:805, in __getattr__(attr)
#     802     import numpy.char as char
#     803     return char.chararray
# --> 805 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'trapz'

# %%
total_power = np.trapezoid(spectra['global'], spectra.index)
print(total_power)
# Out:
# 1000.3706555734423
